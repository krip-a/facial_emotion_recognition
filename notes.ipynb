# %% [markdown]
# ## Workflow
# Input (48×48×1)->
# Conv2D->
# ReLU->
# MaxPooling->
# Conv2D->
# ReLU->
# MaxPooling->
# Flatten->
# Dense->
# Dense (7 outputs)

# %% [markdown]
# ## Conv2D
# Problem: "How do I detect meaningful visual patterns?"

# %% [markdown]
# ## ReLU
# Problem:
# "How do I let the network learn complex relationships instead of behaving like one big linear equation?"

# %% [markdown]
# ## MaxPooling
# Problem:
# "How do I keep the important information while reducing the image size?"

# %% [markdown]
# ## Flatten
# Problem:
# "How do I turn these feature maps into something a classifier can use?"

# %% [markdown]
# ## Dense
# Problem:
# "Given everything I've learned about this face, which emotion is most likely?"

# %% [markdown]
# First Run result:
# too low accuracy, complex dense layers, model memorized train data
#
# Epoch 20/20
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 23s 32ms/step - accuracy: 0.9712 - loss: 0.0940 - val_accuracy: 0.1118 - val_loss: 28.2124
# Model saved to saved_models/emotion_cnn.keras
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.4511 - loss: 8.6681
#
# Test Loss: 8.6681
# Test Accuracy: 0.4511
